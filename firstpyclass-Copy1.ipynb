# %%
5
# Out:
# 5

# %%
a = 5.5

# %%
a
# Out:
# 5.5

# %%
name = input("Enter your name: ")
print("Hello,", name, "! Welcome!")
# Out:
# Enter your name:  simran
# Hello, simran ! Welcome!

# %%
8/3
# Out:
# 2.6666666666666665

# %%
4/2
# Out:
# 2.0

# %%
2/4
# Out:
# 0.5

# %% [markdown]
# 4*2

# %%
 # hiii

# %%
5+5
# Out:
# 10

# %% [markdown]
# #####

# %%
5**4
# Out:
# 625

# %%
5**(1/2)
# Out:
# 2.23606797749979

# %%
8/5
# Out:
# 1.6

# %%
8//5
# Out:
# 1

# %%
8%5
# Out:
# 3

# %%
22/7
# Out:
# 3.142857142857143

# %%
22//7
# Out:
# 3

# %%
a = 5

# %%
a
# Out:
# 5

# %%
a+4
# Out:
# 9

# %%
8/a
# Out:
# 1.6

# %%
5000*(10/100)
# Out:
# 500.0

# %%
500*0.1
# Out:
# 50.0

# %%
a=5

# %%
a
# Out:
# 5

# %%
a=10

# %%
a
# Out:
# 10

# %%
a+a
# Out:
# 20

# %%
a=10 
b=5

# %%
a,b =10,5

# %%
a
b
# Out:
# 5

# %%
print(a)
print(b)
# Out:
# 10
# 5

# %%
c = 'hello'
print(c)
# Out:
# hello

# %%
salary=85200
salary
# Out:
# 85200

# %%
# type() is a built-in function that returns the type of the objects/data elements

# %%
type(85200)
# Out:
# int

# %%
type(8.5)
# Out:
# float

# %%
'simran'
# Out:
# 'simran'

# %%
"simran"
# Out:
# 'simran'

# %%
name='simran'
name
# Out:
# 'simran'

# %%
type(name)
# Out:
# str

# %%
'simran'+'  '+'kaur'
# Out:
# 'simran  kaur'

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
"simran"
print("simran")
# Out:
# simran

# %%
salary=85200
tax_rate=0.12
remaining = salary-tax_rate*salary

# %%
print(remaining)
# Out:
# 74976.0
